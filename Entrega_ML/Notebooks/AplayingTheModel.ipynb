# %%
#Librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
import json
from sklearn.preprocessing import StandardScaler
import lux

# %%
import pandas as pd
test = pd.read_csv('../data/processed/test.csv', index_col=0)
train = pd.read_csv('../data/processed/train.csv', index_col=0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(test)
data_scaled = scaler.transform(test)

# %%
with open('../my_model.pkl', 'rb') as model:
    LGBMRegressor = pickle.load(model)

### Otra opción
# with open('../utils/Inf_Model.json') as json_file:
#     data = json.load(json_file)
#  pd.json_normalize(jason)

# %%
Health_index = LGBMRegressor.predict(data_scaled)

# %%
test['Health index'] = Health_index

# %%
test['Health index'].unique()
# Out:
# array([37.65747892, 37.64984895, 36.19394087, 34.65451488, 34.38003114,
#        34.2266587 , 38.09996266, 34.28307361, 36.04056843, 37.22863384,
#        36.09769532, 37.8296673 , 35.35448237, 35.82591299, 35.40962899,
#        38.4236573 , 34.66672314, 35.50439967, 38.50736372, 35.42069326,
#        34.85448618, 35.03829058, 34.70039026, 34.79489702])

# %%
test.tail(15)
# Out:
# C:\Users\Usuario\AppData\Local\Programs\Python\Python37\lib\site-packages\IPython\core\formatters.py:918: UserWarning:
# Unexpected error in rendering Lux widget and recommendations. Falling back to Pandas display.
# Please report the following issue on Github: https://github.com/lux-org/lux/issues
#
# C:\Users\Usuario\AppData\Local\Programs\Python\Python37\lib\site-packages\lux\core\frame.py:632: UserWarning:Traceback (most recent call last):
#   File "C:\Users\Usuario\AppData\Local\Programs\Python\Python37\lib\site-packages\lux\core\frame.py", line 594, in _ipython_display_
#     self.maintain_recs()
#   File "C:\Users\Usuario\AppData\Local\Programs\Python\Python37\lib\site-packages\lux\core\frame.py", line 436, in maintain_recs
#     custom_action_collection = custom_actions(rec_df)
#   File "C:\Users\Usuario\AppData\Local\Programs\Python\Python37\lib\site-packages\lux\action\custom.py", line 74, in custom_actions
# ...

# %%
test.groupby('Life expectation')['Health index'].value_counts()

# %%
# Represento el histograma
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")

sns.histplot(data=test, x="Health index", color="black", label="Indice de Salud", kde=True)
sns.histplot(data=test, x="Life expectation", color="red", label="Vida Util", kde=True)
# sns.distplot(data["Health index"])
# sns.distplot(data["Life expectation"])

plt.legend() 
plt.title('_Target_')
plt.xlabel('Histograma de dos variables')
plt.show()

# %%
# use the function regplot to make a scatterplot
sns.regplot(x=test["Life expectation"], y=test["Health index"])
# Out:
# <AxesSubplot:xlabel='Life expectation', ylabel='Health index'>

# %%
fig, axes = plt.subplots(7,2, figsize=(15,24))
Health_Indx = test['Health index']
Life = test['Life expectation']
axes = axes.ravel()
for i in range(len(test.columns[:14])):
    axes[i].hist(Health_Indx.unique(), bins = 40, color='r',alpha=0.4)
    axes[i].hist(Life.unique(),bins = 40, color='g',alpha=0.4)
    axes[i].set_title(test.columns[i])

axes[0].legend(['Health_Indx','Life']);
